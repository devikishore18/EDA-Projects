# %% [markdown]
# # IMPORTING ALL ESSENTIAL LIBRARIES

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # READING DATASET AS DF1

# %%
df1=pd.read_csv("hour.csv")
df1
# Out:
#        instant      dteday  season  yr  mnth  hr  holiday  weekday  \
# 0            1  2011-01-01       1   0     1   0        0        6
# 1            2  2011-01-01       1   0     1   1        0        6
# 2            3  2011-01-01       1   0     1   2        0        6
# 3            4  2011-01-01       1   0     1   3        0        6
# 4            5  2011-01-01       1   0     1   4        0        6
# ...        ...         ...     ...  ..   ...  ..      ...      ...
# 17374    17375  2012-12-31       1   1    12  19        0        1
# 17375    17376  2012-12-31       1   1    12  20        0        1
# 17376    17377  2012-12-31       1   1    12  21        0        1
# 17377    17378  2012-12-31       1   1    12  22        0        1
# 17378    17379  2012-12-31       1   1    12  23        0        1
#
#        workingday  weathersit  temp   atemp   hum  windspeed  casual  \
# 0               0           1  0.24  0.2879  0.81     0.0000       3
# 1               0           1  0.22  0.2727  0.80     0.0000       8
# 2               0           1  0.22  0.2727  0.80     0.0000       5
# 3               0           1  0.24  0.2879  0.75     0.0000       3
# 4               0           1  0.24  0.2879  0.75     0.0000       0
# ...           ...         ...   ...     ...   ...        ...     ...
# 17374           1           2  0.26  0.2576  0.60     0.1642      11
# 17375           1           2  0.26  0.2576  0.60     0.1642       8
# 17376           1           1  0.26  0.2576  0.60     0.1642       7
# 17377           1           1  0.26  0.2727  0.56     0.1343      13
# 17378           1           1  0.26  0.2727  0.65     0.1343      12
#
#        registered  cnt
# 0              13   16
# 1              32   40
# 2              27   32
# 3              10   13
# 4               1    1
# ...           ...  ...
# 17374         108  119
# 17375          81   89
# 17376          83   90
# 17377          48   61
# 17378          37   49
#
# [17379 rows x 17 columns]

# %% [markdown]
# # CONVERTING DF1 AS DATAFRAME DF

# %%
df=pd.DataFrame(df1)
df
# Out:
#        instant      dteday  season  yr  mnth  hr  holiday  weekday  \
# 0            1  2011-01-01       1   0     1   0        0        6
# 1            2  2011-01-01       1   0     1   1        0        6
# 2            3  2011-01-01       1   0     1   2        0        6
# 3            4  2011-01-01       1   0     1   3        0        6
# 4            5  2011-01-01       1   0     1   4        0        6
# ...        ...         ...     ...  ..   ...  ..      ...      ...
# 17374    17375  2012-12-31       1   1    12  19        0        1
# 17375    17376  2012-12-31       1   1    12  20        0        1
# 17376    17377  2012-12-31       1   1    12  21        0        1
# 17377    17378  2012-12-31       1   1    12  22        0        1
# 17378    17379  2012-12-31       1   1    12  23        0        1
#
#        workingday  weathersit  temp   atemp   hum  windspeed  casual  \
# 0               0           1  0.24  0.2879  0.81     0.0000       3
# 1               0           1  0.22  0.2727  0.80     0.0000       8
# 2               0           1  0.22  0.2727  0.80     0.0000       5
# 3               0           1  0.24  0.2879  0.75     0.0000       3
# 4               0           1  0.24  0.2879  0.75     0.0000       0
# ...           ...         ...   ...     ...   ...        ...     ...
# 17374           1           2  0.26  0.2576  0.60     0.1642      11
# 17375           1           2  0.26  0.2576  0.60     0.1642       8
# 17376           1           1  0.26  0.2576  0.60     0.1642       7
# 17377           1           1  0.26  0.2727  0.56     0.1343      13
# 17378           1           1  0.26  0.2727  0.65     0.1343      12
#
#        registered  cnt
# 0              13   16
# 1              32   40
# 2              27   32
# 3              10   13
# 4               1    1
# ...           ...  ...
# 17374         108  119
# 17375          81   89
# 17376          83   90
# 17377          48   61
# 17378          37   49
#
# [17379 rows x 17 columns]

# %% [markdown]
# # DESCRIPTIVE ANALYSIS

# %%
df.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %%
df.tail()
# Out:
#        instant      dteday  season  yr  mnth  hr  holiday  weekday  \
# 17374    17375  2012-12-31       1   1    12  19        0        1
# 17375    17376  2012-12-31       1   1    12  20        0        1
# 17376    17377  2012-12-31       1   1    12  21        0        1
# 17377    17378  2012-12-31       1   1    12  22        0        1
# 17378    17379  2012-12-31       1   1    12  23        0        1
#
#        workingday  weathersit  temp   atemp   hum  windspeed  casual  \
# 17374           1           2  0.26  0.2576  0.60     0.1642      11
# 17375           1           2  0.26  0.2576  0.60     0.1642       8
# 17376           1           1  0.26  0.2576  0.60     0.1642       7
# 17377           1           1  0.26  0.2727  0.56     0.1343      13
# 17378           1           1  0.26  0.2727  0.65     0.1343      12
#
#        registered  cnt
# 17374         108  119
# 17375          81   89
# 17376          83   90
# 17377          48   61
# 17378          37   49

# %%
df.shape
# Out:
# (17379, 17)

# %%
df.size
# Out:
# 295443

# %%
df.columns
# Out:
# Index(['instant', 'dteday', 'season', 'yr', 'mnth', 'hr', 'holiday', 'weekday',
#        'workingday', 'weathersit', 'temp', 'atemp', 'hum', 'windspeed',
#        'casual', 'registered', 'cnt'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     17379 non-null  int64
#  1   dteday      17379 non-null  object
#  2   season      17379 non-null  int64
#  3   yr          17379 non-null  int64
#  4   mnth        17379 non-null  int64
#  5   hr          17379 non-null  int64
#  6   holiday     17379 non-null  int64
#  7   weekday     17379 non-null  int64
#  8   workingday  17379 non-null  int64
#  9   weathersit  17379 non-null  int64
#  10  temp        17379 non-null  float64
#  11  atemp       17379 non-null  float64
#  12  hum         17379 non-null  float64
#  13  windspeed   17379 non-null  float64
#  14  casual      17379 non-null  int64
#  15  registered  17379 non-null  int64
#  16  cnt         17379 non-null  int64
# dtypes: float64(4), int64(12), object(1)
# memory usage: 2.3+ MB

# %%
df.describe()
# Out:
#           instant        season            yr          mnth            hr  \
# count  17379.0000  17379.000000  17379.000000  17379.000000  17379.000000
# mean    8690.0000      2.501640      0.502561      6.537775     11.546752
# std     5017.0295      1.106918      0.500008      3.438776      6.914405
# min        1.0000      1.000000      0.000000      1.000000      0.000000
# 25%     4345.5000      2.000000      0.000000      4.000000      6.000000
# 50%     8690.0000      3.000000      1.000000      7.000000     12.000000
# 75%    13034.5000      3.000000      1.000000     10.000000     18.000000
# max    17379.0000      4.000000      1.000000     12.000000     23.000000
#
#             holiday       weekday    workingday    weathersit          temp  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       0.028770      3.003683      0.682721      1.425283      0.496987
# std        0.167165      2.005771      0.465431      0.639357      0.192556
# min        0.000000      0.000000      0.000000      1.000000      0.020000
# 25%        0.000000      1.000000      0.000000      1.000000      0.340000
# 50%        0.000000      3.000000      1.000000      1.000000      0.500000
# 75%        0.000000      5.000000      1.000000      2.000000      0.660000
# max        1.000000      6.000000      1.000000      4.000000      1.000000
#
#               atemp           hum     windspeed        casual    registered  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       0.475775      0.627229      0.190098     35.676218    153.786869
# std        0.171850      0.192930      0.122340     49.305030    151.357286
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.333300      0.480000      0.104500      4.000000     34.000000
# 50%        0.484800      0.630000      0.194000     17.000000    115.000000
# 75%        0.621200      0.780000      0.253700     48.000000    220.000000
# max        1.000000      1.000000      0.850700    367.000000    886.000000
#
#                 cnt
# count  17379.000000
# mean     189.463088
# std      181.387599
# min        1.000000
# 25%       40.000000
# 50%      142.000000
# 75%      281.000000
# max      977.000000

# %%
df.dtypes
# Out:
# instant         int64
# dteday         object
# season          int64
# yr              int64
# mnth            int64
# hr              int64
# holiday         int64
# weekday         int64
# workingday      int64
# weathersit      int64
# temp          float64
# atemp         float64
# hum           float64
# windspeed     float64
# casual          int64
# registered      int64
# cnt             int64
# dtype: object

# %% [markdown]
# # DATA CLEANING

# %%
df.isnull().sum()   # checking for totalno.of null value values.   a missing or unknown value
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
df.isna().sum()        # checking for totalno.of nan value values. an undefined value or value that cannot be represented, especially results of floating-point calculations.
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %% [markdown]
# # checking for any Duplicate Values

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # RENAMING COLUMN NAMES IN DATAFRAME DF

# %%
df=df.rename(columns={'dteday':'date','cnt':'count'})
df.columns
# Out:
# Index(['instant', 'date', 'season', 'yr', 'mnth', 'hr', 'holiday', 'weekday',
#        'workingday', 'weathersit', 'temp', 'atemp', 'hum', 'windspeed',
#        'casual', 'registered', 'count'],
#       dtype='object')

# %% [markdown]
# # REPLACING COLUMN VALUES

# %%
df.replace({'season':{1:'winter',2:'spring',3:'summer',4:'fall'}},inplace=True)
df
# Out:
#        instant        date  season  yr  mnth  hr  holiday  weekday  \
# 0            1  2011-01-01  winter   0     1   0        0        6
# 1            2  2011-01-01  winter   0     1   1        0        6
# 2            3  2011-01-01  winter   0     1   2        0        6
# 3            4  2011-01-01  winter   0     1   3        0        6
# 4            5  2011-01-01  winter   0     1   4        0        6
# ...        ...         ...     ...  ..   ...  ..      ...      ...
# 17374    17375  2012-12-31  winter   1    12  19        0        1
# 17375    17376  2012-12-31  winter   1    12  20        0        1
# 17376    17377  2012-12-31  winter   1    12  21        0        1
# 17377    17378  2012-12-31  winter   1    12  22        0        1
# 17378    17379  2012-12-31  winter   1    12  23        0        1
#
#        workingday  weathersit  temp   atemp   hum  windspeed  casual  \
# 0               0           1  0.24  0.2879  0.81     0.0000       3
# 1               0           1  0.22  0.2727  0.80     0.0000       8
# 2               0           1  0.22  0.2727  0.80     0.0000       5
# 3               0           1  0.24  0.2879  0.75     0.0000       3
# 4               0           1  0.24  0.2879  0.75     0.0000       0
# ...           ...         ...   ...     ...   ...        ...     ...
# 17374           1           2  0.26  0.2576  0.60     0.1642      11
# 17375           1           2  0.26  0.2576  0.60     0.1642       8
# 17376           1           1  0.26  0.2576  0.60     0.1642       7
# 17377           1           1  0.26  0.2727  0.56     0.1343      13
# 17378           1           1  0.26  0.2727  0.65     0.1343      12
#
#        registered  count
# 0              13     16
# 1              32     40
# 2              27     32
# 3              10     13
# 4               1      1
# ...           ...    ...
# 17374         108    119
# 17375          81     89
# 17376          83     90
# 17377          48     61
# 17378          37     49
#
# [17379 rows x 17 columns]

# %%
df.replace({'yr':{0:'2011',1:'2012'}},inplace=True)
df.replace({'mnth':{1:'jan',2:'feb',3:'mar',4:'apr',5:'may',6:'jun',7:'jul',8:'aug',9:'sep',10:'oct',11:'nov',12:'dec'}},inplace=True)
df.replace({'weekday':{0:'sun',1:'mon',2:'tue',3:'wed',4:'thu',5:'fri',6:'sat'}},inplace=True)
df.replace({'workingday':{1:'workday',0:'holiday'}},inplace=True)
df
# Out:
#        instant        date  season    yr mnth  hr  holiday weekday workingday  \
# 0            1  2011-01-01  winter  2011  jan   0        0     sat    holiday
# 1            2  2011-01-01  winter  2011  jan   1        0     sat    holiday
# 2            3  2011-01-01  winter  2011  jan   2        0     sat    holiday
# 3            4  2011-01-01  winter  2011  jan   3        0     sat    holiday
# 4            5  2011-01-01  winter  2011  jan   4        0     sat    holiday
# ...        ...         ...     ...   ...  ...  ..      ...     ...        ...
# 17374    17375  2012-12-31  winter  2012  dec  19        0     mon    workday
# 17375    17376  2012-12-31  winter  2012  dec  20        0     mon    workday
# 17376    17377  2012-12-31  winter  2012  dec  21        0     mon    workday
# 17377    17378  2012-12-31  winter  2012  dec  22        0     mon    workday
# 17378    17379  2012-12-31  winter  2012  dec  23        0     mon    workday
#
#        weathersit  temp   atemp   hum  windspeed  casual  registered  count
# 0               1  0.24  0.2879  0.81     0.0000       3          13     16
# 1               1  0.22  0.2727  0.80     0.0000       8          32     40
# 2               1  0.22  0.2727  0.80     0.0000       5          27     32
# 3               1  0.24  0.2879  0.75     0.0000       3          10     13
# 4               1  0.24  0.2879  0.75     0.0000       0           1      1
# ...           ...   ...     ...   ...        ...     ...         ...    ...
# 17374           2  0.26  0.2576  0.60     0.1642      11         108    119
# 17375           2  0.26  0.2576  0.60     0.1642       8          81     89
# 17376           1  0.26  0.2576  0.60     0.1642       7          83     90
# 17377           1  0.26  0.2727  0.56     0.1343      13          48     61
# 17378           1  0.26  0.2727  0.65     0.1343      12          37     49
#
# [17379 rows x 17 columns]

# %% [markdown]
# # FINDING UNIQUE VALUES AND VALUE COUNTS OF A COLUMN

# %%
c=df['count'].value_counts()
c
# Out:
# count
# 5      260
# 6      236
# 4      231
# 3      224
# 2      208
#       ...
# 938      1
# 826      1
# 963      1
# 708      1
# 636      1
# Name: count, Length: 869, dtype: int64

# %%
df['yr'].value_counts()
# Out:
# yr
# 2012    8734
# 2011    8645
# Name: count, dtype: int64

# %%
df['holiday'].value_counts()
# Out:
# holiday
# 0    16879
# 1      500
# Name: count, dtype: int64

# %%
df['weekday'].value_counts()
# Out:
# weekday
# sat    2512
# sun    2502
# fri    2487
# mon    2479
# wed    2475
# thu    2471
# tue    2453
# Name: count, dtype: int64

# %%
df['weathersit'].value_counts()
# Out:
# weathersit
# 1    11413
# 2     4544
# 3     1419
# 4        3
# Name: count, dtype: int64

# %%
df['temp'].value_counts()  #Normalized temperature in Celsius. The values are derived via (t-t_min)/(t_max-t_min), t_min=-8, t_max=+39 (only in hourly scale)
# Out:
# temp
# 0.62    726
# 0.66    693
# 0.64    692
# 0.70    690
# 0.60    675
# 0.36    671
# 0.34    645
# 0.30    641
# 0.40    614
# 0.32    611
# 0.56    579
# 0.72    570
# 0.54    569
# 0.26    559
# 0.46    559
# 0.52    556
# 0.42    548
# 0.50    531
# 0.24    522
# 0.74    516
# 0.44    507
# 0.22    421
# 0.76    396
# 0.38    372
# 0.20    354
# 0.68    349
# 0.80    325
# 0.58    305
# 0.28    301
# 0.48    288
# 0.16    230
# 0.82    213
# 0.78    169
# 0.18    155
# 0.84    138
# 0.14    138
# 0.86    131
# 0.90     90
# 0.12     76
# 0.88     53
# 0.10     51
# 0.92     49
# 0.94     17
# 0.02     17
# 0.08     17
# 0.06     16
# 0.04     16
# 0.96     16
# 0.98      1
# 1.00      1
# Name: count, dtype: int64

# %%
df['atemp'].value_counts()    #atemp: Normalized feeling temperature in Celsius. The values are derived via (t-t_min)/(t_max-t_min), t_min=-16, t_max=+50 (only in hourly scale)
# Out:
# atemp
# 0.6212    988
# 0.5152    618
# 0.4091    614
# 0.3333    600
# 0.6667    593
#          ...
# 0.0152      4
# 0.0000      2
# 0.9848      2
# 0.9545      1
# 1.0000      1
# Name: count, Length: 65, dtype: int64

# %%
df['hum'].unique()    #Normalized humidity. The values are divided to 100 (max)
# Out:
# array([0.81, 0.8 , 0.75, 0.86, 0.76, 0.77, 0.72, 0.82, 0.88, 0.87, 0.94,
#        1.  , 0.71, 0.66, 0.57, 0.46, 0.42, 0.39, 0.44, 0.47, 0.5 , 0.43,
#        0.4 , 0.35, 0.3 , 0.32, 0.64, 0.69, 0.55, 0.59, 0.63, 0.68, 0.74,
#        0.51, 0.56, 0.52, 0.49, 0.48, 0.37, 0.33, 0.28, 0.38, 0.36, 0.93,
#        0.29, 0.53, 0.34, 0.54, 0.41, 0.45, 0.92, 0.62, 0.58, 0.61, 0.6 ,
#        0.65, 0.7 , 0.27, 0.21, 0.25, 0.26, 0.31, 0.73, 0.24, 0.23, 0.22,
#        0.19, 0.15, 0.67, 0.1 , 0.08, 0.12, 0.14, 0.13, 0.17, 0.16, 0.18,
#        0.96, 0.2 , 0.85, 0.  , 0.9 , 0.83, 0.78, 0.84, 0.89, 0.79, 0.97,
#        0.91])

# %%
df['windspeed'].value_counts()        #Normalized wind speed. The values are divided to 67 (max)
# Out:
# windspeed
# 0.0000    2180
# 0.1343    1738
# 0.1642    1695
# 0.1940    1657
# 0.1045    1617
# 0.2239    1513
# 0.0896    1425
# 0.2537    1295
# 0.2836    1048
# 0.2985     808
# 0.3284     602
# 0.3582     460
# 0.3881     381
# 0.4179     296
# 0.4478     176
# 0.4627     146
# 0.4925     112
# 0.5224      84
# 0.5821      44
# 0.5522      39
# 0.6119      23
# 0.6418      14
# 0.6567      11
# 0.6866       5
# 0.7463       2
# 0.8060       2
# 0.7164       2
# 0.8507       2
# 0.7761       1
# 0.8358       1
# Name: count, dtype: int64

# %%
df['casual'].value_counts()             #count of casual users
# Out:
# casual
# 0      1581
# 1      1082
# 2       798
# 3       697
# 4       561
#        ...
# 239       1
# 231       1
# 289       1
# 292       1
# 304       1
# Name: count, Length: 322, dtype: int64

# %%
df['registered'].unique()             # count of registered users
# Out:
# array([ 13,  32,  27,  10,   1,   0,   2,   7,   6,  24,  30,  55,  47,
#         71,  70,  52,  26,  31,  25,  17,  16,   8,   4,  19,  46,  54,
#         73,  64,  67,  58,  43,  29,  20,   9,   5,   3,  63, 153,  81,
#         33,  41,  48,  53,  66, 146, 148, 102,  49,  11,  36,  92, 177,
#         98,  37,  50,  79,  68, 202, 179, 110,  34,  87, 192, 109,  74,
#         65,  85, 186, 166, 127,  82,  40,  18,  95, 216, 116,  42,  57,
#         78,  59, 163, 158,  51,  76, 190, 125, 178,  39,  14,  15,  56,
#         60,  90,  83,  69,  28,  35,  22,  12,  77,  44,  38,  75, 184,
#        174, 154,  97, 214,  45,  72, 130,  94, 139, 135, 197, 137, 141,
#        156, 117, 155, 134,  89,  80, 108,  61, 124, 132, 196, 107, 100,
#        247, 140,  86,  62, 207, 210, 159, 151, 119,  93,  23, 171, 145,
#        101,  21, 103, 233, 208, 218, 133, 147,  84,  88, 104, 182, 112,
#        114, 172, 165, 105, 183, 175, 170, 217,  91, 195, 152, 126, 115,
#        223, 123, 236, 128, 198, 157, 168,  99, 173, 121, 212, 111, 193,
#        113, 122, 106,  96, 249, 194, 213, 191, 142, 224, 244, 143, 267,
#        256, 211, 161, 131, 246, 118, 164, 275, 120, 188, 227, 206, 181,
#        150, 136, 169, 242, 204, 230, 243, 238, 144, 185, 222, 138, 200,
#        129, 209, 176, 229, 259, 282, 162, 265, 260, 189, 237, 231, 232,
#        199, 312, 271, 245, 221, 228, 239, 220, 268, 252, 205, 308, 283,
#        248, 303, 291, 280, 286, 352, 290, 262, 203, 284, 293, 160, 316,
#        338, 279, 187, 277, 362, 321, 331, 372, 377, 374, 201, 398, 385,
#        309, 346, 402, 381, 272, 226, 215, 326, 441, 425, 320, 149, 254,
#        417, 251, 455, 463, 413, 458, 366, 367, 406, 486, 347, 167, 386,
#        234, 240, 433, 384, 270, 273, 350, 472, 450, 435, 225, 464, 485,
#        323, 388, 266, 255, 415, 467, 456, 305, 470, 253, 235, 263, 351,
#        539, 339, 301, 397, 532, 480, 365, 241, 421, 341, 394, 540, 361,
#        429, 359, 180, 261, 325, 521, 426, 298, 428, 487, 431, 288, 453,
#        454, 345, 289, 476, 269, 483, 274, 373, 302, 403, 492, 490, 310,
#        495, 524, 451, 332, 445, 404, 311, 393, 258, 356, 414, 219, 434,
#        278, 285, 442, 484, 471, 488, 264, 281, 410, 516, 500, 343, 432,
#        475, 479, 355, 329, 400, 423, 529, 510, 348, 473, 335, 555, 527,
#        364, 299, 257, 474, 369, 368, 507, 469, 358, 396, 462, 447, 412,
#        344, 439, 418, 514, 512, 340, 509, 436, 318, 499, 511, 496, 342,
#        324, 391, 466, 297, 517, 489, 382, 380, 295, 333, 276, 478, 287,
#        334, 405, 292, 250, 353, 437, 392, 465, 313, 491, 409, 354, 493,
#        408, 378, 443, 460, 513, 497, 376, 328, 525, 296, 452, 506, 337,
#        537, 461, 502, 519, 387, 370, 314, 317, 459, 549, 440, 567, 349,
#        319, 300, 515, 399, 503, 427, 306, 294, 444, 389, 501, 315, 449,
#        530, 536, 505, 371, 375, 534, 553, 438, 430, 383, 304, 411, 523,
#        448, 407, 422, 379, 330, 401, 363, 446, 481, 498, 518, 508, 522,
#        494, 327, 504, 561, 543, 579, 551, 533, 554, 573, 545, 395, 547,
#        557, 623, 571, 614, 638, 628, 642, 647, 602, 634, 648, 322, 357,
#        563, 615, 681, 665, 616, 627, 598, 656, 654, 360, 693, 593, 625,
#        599, 594, 542, 577, 639, 580, 620, 601, 661, 653, 645, 646, 419,
#        610, 677, 618, 595, 565, 586, 670, 626, 581, 546, 604, 596, 621,
#        564, 589, 631, 673, 651, 663, 668, 697, 558, 619, 664, 649, 575,
#        613, 560, 617, 611, 420, 538, 662, 640, 659, 770, 608, 584, 307,
#        667, 605, 641, 629, 603, 769, 749, 719, 734, 696, 688, 570, 390,
#        468, 716, 709, 336, 678, 416, 588, 674, 632, 457, 756, 746, 675,
#        742, 700, 643, 733, 680, 764, 679, 531, 637, 652, 778, 703, 576,
#        715, 726, 672, 782, 548, 682, 750, 609, 698, 572, 669, 633, 725,
#        704, 600, 591, 535, 562, 757, 691, 622, 796, 730, 597, 658, 741,
#        790, 644, 740, 735, 739, 660, 712, 624, 684, 760, 694, 775, 767,
#        745, 783, 787, 582, 720, 765, 758, 786, 718, 636, 578, 743, 711,
#        689, 751, 424, 699, 552, 768, 723, 810, 592, 811, 695, 744, 774,
#        736, 780, 762, 701, 692, 761, 690, 857, 702, 802, 727, 886, 708,
#        812, 807, 885, 781, 526, 809, 860, 808, 876, 815, 818, 822, 707,
#        791, 833, 544, 789, 655, 806, 773, 737, 706, 566, 713, 800, 839,
#        779, 766, 794, 803, 788, 838, 871, 777, 795, 477, 732, 714, 556,
#        568, 583, 541, 650, 559, 683, 520, 666, 585])

# %%
df['count'].unique()   #count of total rental bikes including both casual and registered
# Out:
# array([ 16,  40,  32,  13,   1,   2,   3,   8,  14,  36,  56,  84,  94,
#        106, 110,  93,  67,  35,  37,  34,  28,  39,  17,   9,   6,  20,
#         53,  70,  75,  59,  74,  76,  65,  30,  22,  31,   5,  64, 154,
#         88,  44,  51,  61,  77,  72, 157,  52,  12,   4, 179, 100,  42,
#         57,  78,  97,  63,  83, 212, 182, 112,  54,  48,  11,  33, 195,
#        115,  46,  79,  71,  62,  89, 190, 169, 132,  43,  19,  95, 219,
#        122,  45,  86, 172, 163,  69,  23,   7, 210, 134,  73,  50,  87,
#        187, 123,  15,  25,  98, 102,  55,  10,  49,  82,  92,  41,  38,
#        188,  47, 178, 155,  24,  18,  27,  99, 217, 130, 136,  29, 128,
#         81,  68, 139, 137, 202,  60, 162, 144, 158, 117,  90, 159, 101,
#        118, 129,  26, 104,  91, 113, 105,  21,  80, 125, 133, 197, 109,
#        161, 249, 143, 215, 185, 152, 126, 166, 120,  96, 103,  58, 116,
#        177, 184, 153, 108, 238, 222, 225, 146, 119, 149, 107, 156, 111,
#        135, 176, 168, 175, 147, 220, 127, 205, 174, 121, 230,  66, 114,
#        216, 243, 199, 170, 165, 160, 140, 211, 145, 256, 223,  85, 206,
#        124, 255, 285, 274, 272, 191, 232, 327, 224, 196, 171, 198, 167,
#        235, 209, 141, 252, 189, 183, 193, 259, 282, 261, 268, 142, 131,
#        214, 242, 148, 201, 150, 228, 204, 164, 233, 257, 151, 248, 194,
#        244, 213, 181, 221, 250, 304, 241, 271, 253, 237, 299, 313, 310,
#        207, 138, 280, 173, 332, 331, 267, 301, 312, 278, 203, 279, 308,
#        226, 276, 336, 307, 273, 227, 239, 254, 287, 294, 263, 192, 281,
#        367, 349, 292, 303, 339, 366, 386, 325, 356, 314, 343, 333, 297,
#        288, 236, 240, 452, 383, 284, 291, 309, 321, 337, 388, 300, 200,
#        180, 354, 361, 306, 277, 428, 362, 286, 351, 411, 421, 396, 432,
#        441, 365, 481, 324, 346, 391, 397, 426, 376, 283, 289, 317, 420,
#        369, 359, 270, 353, 521, 499, 382, 449, 186, 528, 328, 234, 246,
#        444, 218, 412, 260, 398, 455, 530, 404, 269, 508, 439, 416, 464,
#        407, 371, 387, 264, 266, 537, 518, 265, 459, 517, 544, 290, 410,
#        296, 440, 533, 520, 258, 450, 344, 553, 470, 298, 347, 373, 436,
#        378, 342, 340, 390, 358, 385, 374, 598, 524, 384, 425, 611, 550,
#        434, 318, 442, 401, 594, 527, 364, 491, 295, 322, 456, 437, 392,
#        231, 394, 453, 604, 480, 565, 489, 487, 302, 547, 513, 319, 330,
#        554, 473, 323, 418, 493, 462, 506, 471, 305, 316, 409, 429, 548,
#        564, 355, 531, 601, 405, 494, 478, 419, 399, 402, 341, 251, 229,
#        350, 311, 406, 495, 417, 454, 486, 467, 572, 525, 379, 502, 558,
#        293, 247, 451, 335, 363, 357, 438, 579, 556, 334, 477, 539, 551,
#        424, 466, 326, 463, 380, 275, 315, 360, 476, 586, 423, 569, 538,
#        370, 498, 638, 607, 552, 208, 468, 381, 377, 431, 536, 529, 540,
#        400, 352, 557, 375, 443, 403, 447, 591, 504, 570, 588, 320, 555,
#        492, 427, 461, 422, 414, 408, 457, 545, 496, 368, 245, 596, 563,
#        562, 372, 514, 472, 511, 488, 595, 578, 348, 587, 497, 433, 475,
#        430, 262, 485, 546, 541, 483, 338, 543, 413, 435, 523, 532, 585,
#        584, 559, 582, 571, 516, 465, 329, 600, 609, 651, 519, 567, 621,
#        484, 469, 576, 608, 446, 628, 389, 505, 460, 590, 599, 566, 482,
#        568, 415, 589, 345, 593, 393, 500, 479, 620, 625, 614, 395, 445,
#        512, 490, 515, 526, 509, 448, 560, 610, 522, 549, 501, 612, 597,
#        644, 712, 676, 734, 662, 782, 749, 623, 713, 746, 686, 690, 679,
#        685, 648, 503, 721, 801, 750, 535, 729, 779, 649, 810, 957, 830,
#        657, 664, 684, 458, 581, 658, 641, 654, 703, 681, 606, 605, 561,
#        573, 618, 757, 800, 744, 759, 822, 698, 655, 643, 626, 615, 617,
#        632, 646, 692, 704, 624, 656, 738, 671, 678, 660, 635, 616, 673,
#        781, 775, 677, 748, 776, 700, 580, 819, 668, 640, 639, 691, 732,
#        709, 592, 702, 653, 603, 683, 743, 666, 813, 627, 706, 575, 769,
#        680, 717, 710, 622, 705, 630, 770, 659, 602, 733, 650, 873, 846,
#        474, 634, 852, 868, 745, 812, 669, 642, 730, 672, 645, 637, 577,
#        785, 719, 798, 752, 583, 839, 796, 507, 693, 827, 694, 647, 665,
#        834, 850, 790, 724, 869, 793, 723, 534, 831, 613, 857, 867, 823,
#        542, 811, 795, 833, 791, 900, 824, 687, 843, 804, 697, 747, 722,
#        689, 849, 872, 631, 674, 814, 633, 825, 629, 835, 667, 755, 794,
#        661, 772, 771, 777, 715, 847, 741, 877, 788, 913, 891, 688, 699,
#        751, 760, 820, 837, 652, 739, 865, 767, 858, 737, 862, 818, 854,
#        682, 851, 848, 897, 832, 893, 815, 878, 740, 783, 707, 941, 736,
#        845, 864, 808, 870, 754, 844, 853, 856, 725, 863, 792, 696, 701,
#        871, 968, 970, 925, 977, 758, 884, 766, 894, 842, 774, 797, 886,
#        892, 976, 805, 898, 967, 838, 953, 905, 899, 663, 727, 784, 809,
#        917, 901, 887, 761, 806, 948, 670, 619, 943, 817, 888, 890, 714,
#        711, 731, 675, 728, 922, 786, 938, 826, 963, 708, 636])

# %% [markdown]
# # PLOTING USING MATPLOTLIB AND SEABORN

# %% [markdown]
# ## SCATTER PLOTS

# %%
plt.scatter(df['mnth'],df['count'])
plt.xlabel('month of the year')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %%
sns.scatterplot(x=df['mnth'],y=df['count'],data=df)
plt.title('scatter plot using sns')
# Out:
# Text(0.5, 1.0, 'scatter plot using sns')

# %%
sns.scatterplot(x=df['temp'],y=df['atemp'],data=df)
plt.title('Normalized temperature vs Normalized feeling temperature in Celsius')
# Out:
# Text(0.5, 1.0, 'Normalized temperature vs Normalized feeling temperature in Celsius')

# %% [markdown]
# ## LINE PLOTS

# %%
sns.lineplot(x=df['mnth'],y=df['count'],data=df)
plt.title('line plot using sns')
# Out:
# Text(0.5, 1.0, 'line plot using sns')

# %%
plt.plot(df['mnth'],df['count'])

# %% [markdown]
# ## HISTPLOTS

# %%
sns.histplot(data=df,x='count',bins=40,kde=True)
plt.title('Distribution of Bike Rental Counts')
plt.xlabel('Count')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
plt.hist(df['count'],bins=5)
plt.title('Distribution of Bike Rental Counts')
plt.xlabel('Count')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
sns.histplot(data=df,x='atemp',bins=10,kde=True)
# Out:
# <Axes: xlabel='atemp', ylabel='Count'>

# %% [markdown]
# ## BAR PLOTS

# %%
plt.bar(df['mnth'],df['count'])
plt.show()

# %%
sns.barplot(x='yr',y='count',data=df)
plt.show()

# %% [markdown]
# ## Pie Plot

# %%
season_counts = df.groupby('season')['count'].sum()
plt.figure(figsize=(6, 6))
plt.pie(season_counts, labels=season_counts.index, autopct='%1.1f%%', 
        startangle=140, colors=['#ff9999', '#66b3ff', '#99ff99', '#ffcc99'])
plt.title('Total Bike Rentals by Season')
plt.axis('equal')  # Equal aspect ratio to ensure the pie is circular
plt.show()

# %%
df['cnt_class'] = pd.cut(df['count'], bins=[0, 100, 300, df['count'].max()], 
                         labels=['Low', 'Medium', 'High'])
demand_counts = df['cnt_class'].value_counts().sort_index()  # Count distribution
plt.pie(demand_counts, labels=demand_counts.index, autopct='%1.1f%%', 
        startangle=140, colors=['#66b3ff', '#99ff99', '#ff9999'])
plt.title('Distribution of Bike Rental Demand Levels')
plt.axis('equal')  # Ensures pie is drawn as a circle
plt.show()

# %% [markdown]
# ## Boxplots

# %%
numeric_cols = ['temp', 'atemp', 'hum', 'windspeed', 'count']
plt.figure(figsize=(12, 6))
sns.boxplot(data=df[numeric_cols])
plt.title('Boxplot of Key Numerical Features')
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
df.dtypes
# Out:
# instant          int64
# date            object
# season          object
# yr              object
# mnth            object
# hr               int64
# holiday          int64
# weekday         object
# workingday      object
# weathersit       int64
# temp           float64
# atemp          float64
# hum            float64
# windspeed      float64
# casual           int64
# registered       int64
# count            int64
# cnt_class     category
# dtype: object

# %% [markdown]
# # Statistical Analysis

# %% [markdown]
# ## Checking for Skewness for all numerical columns

# %%
a=df.select_dtypes(include='number').skew()
a
# Out:
# instant       0.000000
# hr           -0.010680
# holiday       5.638538
# weathersit    1.228047
# temp         -0.006021
# atemp        -0.090429
# hum          -0.111287
# windspeed     0.574905
# casual        2.499237
# registered    1.557904
# count         1.277412
# dtype: float64

# %% [markdown]
# ## find mean value for all numerical columns

# %%
b=df.select_dtypes(include='number').mean()
b
# Out:
# instant       8690.000000
# hr              11.546752
# holiday          0.028770
# weathersit       1.425283
# temp             0.496987
# atemp            0.475775
# hum              0.627229
# windspeed        0.190098
# casual          35.676218
# registered     153.786869
# count          189.463088
# dtype: float64

# %% [markdown]
# ## Finding correlations between all numerical columns

# %%
co=df.select_dtypes(include='number').corr()
co
# Out:
#              instant        hr   holiday  weathersit      temp     atemp  \
# instant     1.000000 -0.004775  0.014723   -0.014198  0.136178  0.137615
# hr         -0.004775  1.000000  0.000479   -0.020203  0.137603  0.133750
# holiday     0.014723  0.000479  1.000000   -0.017036 -0.027340 -0.030973
# weathersit -0.014198 -0.020203 -0.017036    1.000000 -0.102640 -0.105563
# temp        0.136178  0.137603 -0.027340   -0.102640  1.000000  0.987672
# atemp       0.137615  0.133750 -0.030973   -0.105563  0.987672  1.000000
# hum         0.009577 -0.276498 -0.010588    0.418130 -0.069881 -0.051918
# windspeed  -0.074505  0.137252  0.003988    0.026226 -0.023125 -0.062336
# casual      0.158295  0.301202  0.031564   -0.152628  0.459616  0.454080
# registered  0.282046  0.374141 -0.047345   -0.120966  0.335361  0.332559
# count       0.278379  0.394071 -0.030927   -0.142426  0.404772  0.400929
#
#                  hum  windspeed    casual  registered     count
# instant     0.009577  -0.074505  0.158295    0.282046  0.278379
# hr         -0.276498   0.137252  0.301202    0.374141  0.394071
# holiday    -0.010588   0.003988  0.031564   -0.047345 -0.030927
# weathersit  0.418130   0.026226 -0.152628   -0.120966 -0.142426
# temp       -0.069881  -0.023125  0.459616    0.335361  0.404772
# atemp      -0.051918  -0.062336  0.454080    0.332559  0.400929
# hum         1.000000  -0.290105 -0.347028   -0.273933 -0.322911
# windspeed  -0.290105   1.000000  0.090287    0.082321  0.093234
# casual     -0.347028   0.090287  1.000000    0.506618  0.694564
# registered -0.273933   0.082321  0.506618    1.000000  0.972151
# count      -0.322911   0.093234  0.694564    0.972151  1.000000

# %%
pearson = df['atemp'].corr(df['count'], method='pearson')
pearson
# Out:
# np.float64(0.4009293041266319)

# %% [markdown]
# ## Kurtosis

# %%
k=df.select_dtypes(include='number').kurt()
k
# Out:
# instant       -1.200000
# hr            -1.198021
# holiday       29.796540
# weathersit     0.350151
# temp          -0.941844
# atemp         -0.845412
# hum           -0.826117
# windspeed      0.590820
# casual         7.571002
# registered     2.750018
# count          1.417203
# dtype: float64

# %% [markdown]
# ## Outlier detection using box plot

# %%
sns.boxplot(data=df)
# Out:
# <Axes: >

# %% [markdown]
# # Caping/Imputing outlier data point using IQR

# %%
for col in df.select_dtypes(include='number').columns:
    q1=df[col].quantile(0.25)
    q3=df[col].quantile(0.75)
    iqr=q3-q1
    #define bounds(lower and upper)
    lower_bound=q1-1.5*iqr
    upper_bound=q3+1.5*iqr
    #removing outliers
    clean_data=df[(df[col]>=lower_bound) & (df[col]<=upper_bound)][col]

# %% [markdown]
#  # Function to apply IQR method to fix outliers

# %%
def fix_outliers_iqr(df):
    num=df.select_dtypes(include='number').columns
    for col in num:
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR
# Replace outliers with the respective bounds
        df[col] = df[col].apply(lambda x: lower_bound if x < lower_bound else upper_bound if x > upper_bound else x)
    return df

# %% [markdown]
# ## Creating a new dataframe with a function fix_outliers_iqr

# %%
df1=fix_outliers_iqr(df)
df1.head(2)
# Out:
#    instant        date  season    yr mnth  hr  holiday weekday workingday  \
# 0        1  2011-01-01  winter  2011  jan   0      0.0     sat    holiday
# 1        2  2011-01-01  winter  2011  jan   1      0.0     sat    holiday
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  count  \
# 0         1.0  0.24  0.2879  0.81        0.0     3.0        13.0   16.0
# 1         1.0  0.22  0.2727  0.80        0.0     8.0        32.0   40.0
#
#   cnt_class
# 0       Low
# 1       Low

# %% [markdown]
# # Visualising a box plot with capped or imputed outliers

# %%
sns.boxplot(data=df1)
# Out:
# <Axes: >

# %% [markdown]
# # Finding correlation between numerical columns and plotting heat map

# %%
co
# Out:
#              instant        hr   holiday  weathersit      temp     atemp  \
# instant     1.000000 -0.004775  0.014723   -0.014198  0.136178  0.137615
# hr         -0.004775  1.000000  0.000479   -0.020203  0.137603  0.133750
# holiday     0.014723  0.000479  1.000000   -0.017036 -0.027340 -0.030973
# weathersit -0.014198 -0.020203 -0.017036    1.000000 -0.102640 -0.105563
# temp        0.136178  0.137603 -0.027340   -0.102640  1.000000  0.987672
# atemp       0.137615  0.133750 -0.030973   -0.105563  0.987672  1.000000
# hum         0.009577 -0.276498 -0.010588    0.418130 -0.069881 -0.051918
# windspeed  -0.074505  0.137252  0.003988    0.026226 -0.023125 -0.062336
# casual      0.158295  0.301202  0.031564   -0.152628  0.459616  0.454080
# registered  0.282046  0.374141 -0.047345   -0.120966  0.335361  0.332559
# count       0.278379  0.394071 -0.030927   -0.142426  0.404772  0.400929
#
#                  hum  windspeed    casual  registered     count
# instant     0.009577  -0.074505  0.158295    0.282046  0.278379
# hr         -0.276498   0.137252  0.301202    0.374141  0.394071
# holiday    -0.010588   0.003988  0.031564   -0.047345 -0.030927
# weathersit  0.418130   0.026226 -0.152628   -0.120966 -0.142426
# temp       -0.069881  -0.023125  0.459616    0.335361  0.404772
# atemp      -0.051918  -0.062336  0.454080    0.332559  0.400929
# hum         1.000000  -0.290105 -0.347028   -0.273933 -0.322911
# windspeed  -0.290105   1.000000  0.090287    0.082321  0.093234
# casual     -0.347028   0.090287  1.000000    0.506618  0.694564
# registered -0.273933   0.082321  0.506618    1.000000  0.972151
# count      -0.322911   0.093234  0.694564    0.972151  1.000000

# %%
plt.figure(figsize=(15,20))
sns.heatmap(co,annot=True,cmap='YlGnBu')
plt.show()

# %% [markdown]
# ## SKEWNESS USING POWER TRANSFORMER FROM SKLEARN

# %%
from sklearn.preprocessing import PowerTransformer
pt=PowerTransformer(method='yeo-johnson')
numeric_cols = df.select_dtypes(include=['float64', 'int64']).columns

# %%
df_transformed = pd.DataFrame(
    pt.fit_transform(df[numeric_cols]),
    columns=numeric_cols
)

# %%
df_transformed.skew()
# Out:
# instant      -0.290779
# hr           -0.244558
# holiday       0.000000
# weathersit    0.680252
# temp         -0.035287
# atemp        -0.042424
# hum          -0.045369
# windspeed     0.007055
# casual       -0.076914
# registered   -0.154369
# count        -0.155453
# dtype: float64

# %% [markdown]
# ## Plotting Histplot

# %%
plt.figure(figsize=(20, 10))
for i, col in enumerate(numeric_cols):
    plt.subplot(1, len(numeric_cols), i + 1)
    sns.histplot(df_transformed[col], kde=True, bins=20, color='skyblue')
    plt.title(f"{col} (Transformed)")
    plt.xlabel('')
    plt.ylabel('')

# %%
# Plot each column individually
for col in numeric_cols:
    plt.figure(figsize=(6, 4))
    sns.histplot(df_transformed[col], kde=True, bins=20, color='teal')
    plt.title(f"{col} (Transformed)")
    plt.xlabel(col)
    plt.ylabel("Frequency")
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Encoding Target Variable using LabelEncoder from Sklearn.preprocessing

# %%
df
# Out:
#        instant        date  season    yr mnth  hr  holiday weekday workingday  \
# 0            1  2011-01-01  winter  2011  jan   0      0.0     sat    holiday
# 1            2  2011-01-01  winter  2011  jan   1      0.0     sat    holiday
# 2            3  2011-01-01  winter  2011  jan   2      0.0     sat    holiday
# 3            4  2011-01-01  winter  2011  jan   3      0.0     sat    holiday
# 4            5  2011-01-01  winter  2011  jan   4      0.0     sat    holiday
# ...        ...         ...     ...   ...  ...  ..      ...     ...        ...
# 17374    17375  2012-12-31  winter  2012  dec  19      0.0     mon    workday
# 17375    17376  2012-12-31  winter  2012  dec  20      0.0     mon    workday
# 17376    17377  2012-12-31  winter  2012  dec  21      0.0     mon    workday
# 17377    17378  2012-12-31  winter  2012  dec  22      0.0     mon    workday
# 17378    17379  2012-12-31  winter  2012  dec  23      0.0     mon    workday
#
#        weathersit  temp   atemp   hum  windspeed  casual  registered  count  \
# 0             1.0  0.24  0.2879  0.81     0.0000     3.0        13.0   16.0
# 1             1.0  0.22  0.2727  0.80     0.0000     8.0        32.0   40.0
# 2             1.0  0.22  0.2727  0.80     0.0000     5.0        27.0   32.0
# 3             1.0  0.24  0.2879  0.75     0.0000     3.0        10.0   13.0
# 4             1.0  0.24  0.2879  0.75     0.0000     0.0         1.0    1.0
# ...           ...   ...     ...   ...        ...     ...         ...    ...
# 17374         2.0  0.26  0.2576  0.60     0.1642    11.0       108.0  119.0
# 17375         2.0  0.26  0.2576  0.60     0.1642     8.0        81.0   89.0
# 17376         1.0  0.26  0.2576  0.60     0.1642     7.0        83.0   90.0
# 17377         1.0  0.26  0.2727  0.56     0.1343    13.0        48.0   61.0
# 17378         1.0  0.26  0.2727  0.65     0.1343    12.0        37.0   49.0
#
#       cnt_class
# 0           Low
# 1           Low
# 2           Low
# 3           Low
# 4           Low
# ...         ...
# 17374    Medium
# 17375       Low
# 17376       Low
# 17377       Low
# 17378       Low
#
# [17379 rows x 18 columns]

# %% [markdown]
# ## Encoding Target Variable using LabelEncoder from Sklearn.preprocessing

# %%
from sklearn.preprocessing import LabelEncoder
le= LabelEncoder()
df['cnt_class']=le.fit_transform(df[['cnt_class']])
df
# Out:
# C:\Users\Admin\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_label.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#        instant        date  season    yr mnth  hr  holiday weekday workingday  \
# 0            1  2011-01-01  winter  2011  jan   0      0.0     sat    holiday
# 1            2  2011-01-01  winter  2011  jan   1      0.0     sat    holiday
# 2            3  2011-01-01  winter  2011  jan   2      0.0     sat    holiday
# 3            4  2011-01-01  winter  2011  jan   3      0.0     sat    holiday
# 4            5  2011-01-01  winter  2011  jan   4      0.0     sat    holiday
# ...        ...         ...     ...   ...  ...  ..      ...     ...        ...
# 17374    17375  2012-12-31  winter  2012  dec  19      0.0     mon    workday
# 17375    17376  2012-12-31  winter  2012  dec  20      0.0     mon    workday
# 17376    17377  2012-12-31  winter  2012  dec  21      0.0     mon    workday
# 17377    17378  2012-12-31  winter  2012  dec  22      0.0     mon    workday
# 17378    17379  2012-12-31  winter  2012  dec  23      0.0     mon    workday
#
#        weathersit  temp   atemp   hum  windspeed  casual  registered  count  \
# 0             1.0  0.24  0.2879  0.81     0.0000     3.0        13.0   16.0
# 1             1.0  0.22  0.2727  0.80     0.0000     8.0        32.0   40.0
# 2             1.0  0.22  0.2727  0.80     0.0000     5.0        27.0   32.0
# 3             1.0  0.24  0.2879  0.75     0.0000     3.0        10.0   13.0
# 4             1.0  0.24  0.2879  0.75     0.0000     0.0         1.0    1.0
# ...           ...   ...     ...   ...        ...     ...         ...    ...
# 17374         2.0  0.26  0.2576  0.60     0.1642    11.0       108.0  119.0
# 17375         2.0  0.26  0.2576  0.60     0.1642     8.0        81.0   89.0
# 17376         1.0  0.26  0.2576  0.60     0.1642     7.0        83.0   90.0
# 17377         1.0  0.26  0.2727  0.56     0.1343    13.0        48.0   61.0
# 17378         1.0  0.26  0.2727  0.65     0.1343    12.0        37.0   49.0
#
#        cnt_class
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1
# ...          ...
# 17374          2
# 17375          1
# 17376          1
# 17377          1
# 17378          1
#
# [17379 rows x 18 columns]

# %% [markdown]
# # Encoding using One hot Encoder from sklearn.preprocessing

# %%
columns_to_encode = ['yr', 'mnth', 'weekday', 'workingday', 'season']
df_encoded = pd.get_dummies(df, columns=columns_to_encode, drop_first=True)
df_encoded
# Out:
#        instant        date  hr  holiday  weathersit  temp   atemp   hum  \
# 0            1  2011-01-01   0      0.0         1.0  0.24  0.2879  0.81
# 1            2  2011-01-01   1      0.0         1.0  0.22  0.2727  0.80
# 2            3  2011-01-01   2      0.0         1.0  0.22  0.2727  0.80
# 3            4  2011-01-01   3      0.0         1.0  0.24  0.2879  0.75
# 4            5  2011-01-01   4      0.0         1.0  0.24  0.2879  0.75
# ...        ...         ...  ..      ...         ...   ...     ...   ...
# 17374    17375  2012-12-31  19      0.0         2.0  0.26  0.2576  0.60
# 17375    17376  2012-12-31  20      0.0         2.0  0.26  0.2576  0.60
# 17376    17377  2012-12-31  21      0.0         1.0  0.26  0.2576  0.60
# 17377    17378  2012-12-31  22      0.0         1.0  0.26  0.2727  0.56
# 17378    17379  2012-12-31  23      0.0         1.0  0.26  0.2727  0.65
#
#        windspeed  casual  ...  weekday_mon  weekday_sat  weekday_sun  \
# 0         0.0000     3.0  ...        False         True        False
# 1         0.0000     8.0  ...        False         True        False
# 2         0.0000     5.0  ...        False         True        False
# 3         0.0000     3.0  ...        False         True        False
# 4         0.0000     0.0  ...        False         True        False
# ...          ...     ...  ...          ...          ...          ...
# 17374     0.1642    11.0  ...         True        False        False
# 17375     0.1642     8.0  ...         True        False        False
# 17376     0.1642     7.0  ...         True        False        False
# 17377     0.1343    13.0  ...         True        False        False
# 17378     0.1343    12.0  ...         True        False        False
#
#        weekday_thu  weekday_tue  weekday_wed  workingday_workday  \
# 0            False        False        False               False
# 1            False        False        False               False
# 2            False        False        False               False
# 3            False        False        False               False
# 4            False        False        False               False
# ...            ...          ...          ...                 ...
# 17374        False        False        False                True
# 17375        False        False        False                True
# 17376        False        False        False                True
# 17377        False        False        False                True
# 17378        False        False        False                True
#
#        season_spring  season_summer  season_winter
# 0              False          False           True
# 1              False          False           True
# 2              False          False           True
# 3              False          False           True
# 4              False          False           True
# ...              ...            ...            ...
# 17374          False          False           True
# 17375          False          False           True
# 17376          False          False           True
# 17377          False          False           True
# 17378          False          False           True
#
# [17379 rows x 35 columns]

# %%
cols_to_encode = ['season', 'yr', 'mnth', 'weekday', 'workingday','date']
label_encoders = {}
for col in cols_to_encode:
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col])
    label_encoders[col] = le

print(df.head())
# Out:
#    instant  date  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1     0       3   0     4   0      0.0        2           0
# 1        2     0       3   0     4   1      0.0        2           0
# 2        3     0       3   0     4   2      0.0        2           0
# 3        4     0       3   0     4   3      0.0        2           0
# 4        5     0       3   0     4   4      0.0        2           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  count  \
# 0         1.0  0.24  0.2879  0.81        0.0     3.0        13.0   16.0
# 1         1.0  0.22  0.2727  0.80        0.0     8.0        32.0   40.0
# 2         1.0  0.22  0.2727  0.80        0.0     5.0        27.0   32.0
# 3         1.0  0.24  0.2879  0.75        0.0     3.0        10.0   13.0
# 4         1.0  0.24  0.2879  0.75        0.0     0.0         1.0    1.0
#
#    cnt_class
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1

# %%
df
# Out:
#        instant  date  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0            1     0       3   0     4   0      0.0        2           0
# 1            2     0       3   0     4   1      0.0        2           0
# 2            3     0       3   0     4   2      0.0        2           0
# 3            4     0       3   0     4   3      0.0        2           0
# 4            5     0       3   0     4   4      0.0        2           0
# ...        ...   ...     ...  ..   ...  ..      ...      ...         ...
# 17374    17375   730       3   1     2  19      0.0        1           1
# 17375    17376   730       3   1     2  20      0.0        1           1
# 17376    17377   730       3   1     2  21      0.0        1           1
# 17377    17378   730       3   1     2  22      0.0        1           1
# 17378    17379   730       3   1     2  23      0.0        1           1
#
#        weathersit  temp   atemp   hum  windspeed  casual  registered  count  \
# 0             1.0  0.24  0.2879  0.81     0.0000     3.0        13.0   16.0
# 1             1.0  0.22  0.2727  0.80     0.0000     8.0        32.0   40.0
# 2             1.0  0.22  0.2727  0.80     0.0000     5.0        27.0   32.0
# 3             1.0  0.24  0.2879  0.75     0.0000     3.0        10.0   13.0
# 4             1.0  0.24  0.2879  0.75     0.0000     0.0         1.0    1.0
# ...           ...   ...     ...   ...        ...     ...         ...    ...
# 17374         2.0  0.26  0.2576  0.60     0.1642    11.0       108.0  119.0
# 17375         2.0  0.26  0.2576  0.60     0.1642     8.0        81.0   89.0
# 17376         1.0  0.26  0.2576  0.60     0.1642     7.0        83.0   90.0
# 17377         1.0  0.26  0.2727  0.56     0.1343    13.0        48.0   61.0
# 17378         1.0  0.26  0.2727  0.65     0.1343    12.0        37.0   49.0
#
#        cnt_class
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1
# ...          ...
# 17374          2
# 17375          1
# 17376          1
# 17377          1
# 17378          1
#
# [17379 rows x 18 columns]

# %% [markdown]
# # smote technique

# %%
from imblearn.over_sampling import SMOTE
smote= SMOTE()

# %%
x_smote, y_smote = smote.fit_resample(df1[(i for i in list(df1.describe(include='all').columns) if i != 'cnt_class')], df1['cnt_class'])

# %%
print('length of y smote',len(y_smote))
# Out:
# length of y smote 21105

# %%
balanced_df = pd.DataFrame(x_smote, columns=list(i for i in list(df1.describe(include='all').columns) if i != 'cnt_class'))

# %%
balanced_df['cnt_class'] = y_smote
balanced_df
# Out:
#        instant  date  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0            1     0       3   0     4   0      0.0        2           0
# 1            2     0       3   0     4   1      0.0        2           0
# 2            3     0       3   0     4   2      0.0        2           0
# 3            4     0       3   0     4   3      0.0        2           0
# 4            5     0       3   0     4   4      0.0        2           0
# ...        ...   ...     ...  ..   ...  ..      ...      ...         ...
# 21100     8117   342       0   0     2  20      0.0        0           1
# 21101     3273   139       1   0     8  18      0.0        1           0
# 21102     5105   216       2   0     1  14      0.0        0           1
# 21103     9803   413       3   1     3   9      0.0        2           0
# 21104     4639   196       2   0     5  15      0.0        2           0
#
#        weathersit      temp     atemp       hum  windspeed     casual  \
# 0        1.000000  0.240000  0.287900  0.810000   0.000000   3.000000
# 1        1.000000  0.220000  0.272700  0.800000   0.000000   8.000000
# 2        1.000000  0.220000  0.272700  0.800000   0.000000   5.000000
# 3        1.000000  0.240000  0.287900  0.750000   0.000000   3.000000
# 4        1.000000  0.240000  0.287900  0.750000   0.000000   0.000000
# ...           ...       ...       ...       ...        ...        ...
# 21100    1.000000  0.300000  0.333300  0.786777   0.000000   9.612947
# 21101    1.000000  0.609425  0.605178  0.614602   0.176523  72.345184
# 21102    1.109218  0.762184  0.698649  0.546723   0.253700  53.385760
# 21103    1.000000  0.238616  0.286806  0.824307   0.025258  11.269246
# 21104    1.000000  0.700357  0.651820  0.594733   0.223900  67.615909
#
#        registered       count  cnt_class
# 0       13.000000   16.000000          1
# 1       32.000000   40.000000          1
# 2       27.000000   32.000000          1
# 3       10.000000   13.000000          1
# 4        1.000000    1.000000          1
# ...           ...         ...        ...
# 21100  136.516525  146.129473          2
# 21101  128.356173  200.701357          2
# 21102  160.436872  213.822632          2
# 21103   91.746151  103.015396          2
# 21104  108.526748  176.142657          2
#
# [21105 rows x 18 columns]

# %% [markdown]
# ## FEATURE SELECTION

# %%
from sklearn.feature_selection import SelectKBest,f_classif       #f_regressor
skb= SelectKBest(score_func=f_classif,k=10)
y= balanced_df['cnt_class']
X= balanced_df.drop('cnt_class', axis=1)

# %%
X.columns
# Out:
# Index(['instant', 'date', 'season', 'yr', 'mnth', 'hr', 'holiday', 'weekday',
#        'workingday', 'weathersit', 'temp', 'atemp', 'hum', 'windspeed',
#        'casual', 'registered', 'count'],
#       dtype='object')

# %%
y
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 21100    2
# 21101    2
# 21102    2
# 21103    2
# 21104    2
# Name: cnt_class, Length: 21105, dtype: int64

# %%
X_new = skb.fit_transform(X , y)
# Out:
# C:\Users\Admin\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:111: UserWarning: Features [6] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx, UserWarning)
# C:\Users\Admin\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:112: RuntimeWarning: invalid value encountered in divide
#   f = msb / msw

# %%
selected_columns= X.columns[skb.get_support()]
selected_columns
# Out:
# Index(['instant', 'date', 'yr', 'hr', 'temp', 'atemp', 'hum', 'casual',
#        'registered', 'count'],
#       dtype='object')

# %% [markdown]
# # feature selection score for each columns

# %%
feature_scores = pd.DataFrame({
    'Feature': X.columns,
    'Score': skb.scores_
}).sort_values(by='Score', ascending=False)
feature_scores
# Out:
#        Feature         Score
# 16       count  57137.459282
# 15  registered  43826.944748
# 14      casual  11707.814901
# 5           hr   3301.377085
# 10        temp   2481.181697
# 11       atemp   2461.470105
# 12         hum   1456.025395
# 0      instant    854.023785
# 1         date    849.095012
# 3           yr    609.660108
# 2       season    329.909569
# 9   weathersit    254.209715
# 13   windspeed    127.220809
# 4         mnth    116.645708
# 8   workingday     78.036098
# 7      weekday      7.980084
# 6      holiday           NaN

# %%
X_selected= X[selected_columns]
X_selected
# Out:
#        instant  date  yr  hr      temp     atemp       hum     casual  \
# 0            1     0   0   0  0.240000  0.287900  0.810000   3.000000
# 1            2     0   0   1  0.220000  0.272700  0.800000   8.000000
# 2            3     0   0   2  0.220000  0.272700  0.800000   5.000000
# 3            4     0   0   3  0.240000  0.287900  0.750000   3.000000
# 4            5     0   0   4  0.240000  0.287900  0.750000   0.000000
# ...        ...   ...  ..  ..       ...       ...       ...        ...
# 21100     8117   342   0  20  0.300000  0.333300  0.786777   9.612947
# 21101     3273   139   0  18  0.609425  0.605178  0.614602  72.345184
# 21102     5105   216   0  14  0.762184  0.698649  0.546723  53.385760
# 21103     9803   413   1   9  0.238616  0.286806  0.824307  11.269246
# 21104     4639   196   0  15  0.700357  0.651820  0.594733  67.615909
#
#        registered       count
# 0       13.000000   16.000000
# 1       32.000000   40.000000
# 2       27.000000   32.000000
# 3       10.000000   13.000000
# 4        1.000000    1.000000
# ...           ...         ...
# 21100  136.516525  146.129473
# 21101  128.356173  200.701357
# 21102  160.436872  213.822632
# 21103   91.746151  103.015396
# 21104  108.526748  176.142657
#
# [21105 rows x 10 columns]

# %% [markdown]
# # SCALING (0-1)
# - Standard scaler(0-1)
# - Min-Max scaler

# %%
from sklearn.preprocessing import StandardScaler
ss= StandardScaler()
X_scaled= ss.fit_transform(X_selected)
X_scaled
# Out:
# array([[-1.80820346, -1.81960368, -1.06033391, ..., -0.91108098,
#         -1.12422621, -1.11910266],
#        [-1.80800278, -1.81960368, -1.06033391, ..., -0.77815708,
#         -0.99555945, -0.99114778],
#        [-1.80780209, -1.81960368, -1.06033391, ..., -0.85791142,
#         -1.02941912, -1.03379941],
#        ...,
#        [-0.78389281, -0.78403748, -1.06033391, ...,  0.42841334,
#         -0.12579331, -0.06442053],
#        [ 0.15893859,  0.16043725,  0.94309914, ..., -0.69124491,
#         -0.5909624 , -0.65518414],
#        [-0.87741334, -0.87992324, -1.06033391, ...,  0.80671871,
#         -0.47732529, -0.26530956]], shape=(21105, 10))

# %% [markdown]
# # Training and testing

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test= train_test_split(X_scaled,y,test_size=0.2,random_state=40)

# %%
print('X_train Shape:',X_train.shape)
print('X_test Shape:',X_test.shape)
print('y_train Shape:',y_train.shape)
print('y_test Shape:',y_test.shape)
# Out:
# X_train Shape: (16884, 10)
# X_test Shape: (4221, 10)
# y_train Shape: (16884,)
# y_test Shape: (4221,)

# %%
y.value_counts()    #imbalanced data, oversampling
# Out:
# cnt_class
# 1    7035
# 2    7035
# 0    7035
# Name: count, dtype: int64
