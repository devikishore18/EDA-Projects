# %% [markdown]
# # IMPORTING ESSENTIAL LIBRARIES

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # LOADING A FILE AS DATA

# %%
data=pd.read_csv('corporate_work_hours_productivity.csv')
data
# Out:
#       Employee_ID  Age Department Job_Level  Years_at_Company  \
# 0               1   45  Marketing       Mid                29
# 1               2   38  Marketing       Mid                 7
# 2               3   53      Sales       Mid                 8
# 3               4   46    Finance       Mid                 4
# 4               5   28    Finance   Manager                 5
# ...           ...  ...        ...       ...               ...
# 9995         9996   54      Sales     Entry                18
# 9996         9997   37      Sales       Mid                27
# 9997         9998   56    Finance    Senior                20
# 9998         9999   57         IT    Senior                13
# 9999        10000   22         HR    Senior                19
#
#       Monthly_Hours_Worked Remote_Work  Meetings_per_Week  \
# 0                      198          No                  1
# 1                      157         Yes                 13
# 2                      146          No                  2
# 3                      200          No                  4
# 4                      193      Hybrid                 11
# ...                    ...         ...                ...
# 9995                   133          No                 14
# 9996                   187          No                  5
# 9997                   125          No                  9
# 9998                   123          No                  7
# 9999                   188          No                  1
#
#       Tasks_Completed_Per_Day  Overtime_Hours_Per_Week Work_Life_Balance  \
# 0                           7                        1              Good
# 1                           3                       10         Excellent
# 2                          15                       11              Poor
# 3                           9                        0              Poor
# 4                           9                        6              Poor
# ...                       ...                      ...               ...
# 9995                       10                        8              Good
# 9996                       15                        3              Good
# 9997                        4                       12           Average
# 9998                        7                        5           Average
# 9999                        4                        2              Poor
#
#       Job_Satisfaction  Productivity_Score  Annual_Salary  Absences_Per_Year
# 0                    5               88.73         182971                  2
# 1                    1               74.70          74217                 13
# 2                    4               67.85         176003                 16
# 3                    5               93.73          69209                  1
# 4                    7               93.30         195477                  5
# ...                ...                 ...            ...                ...
# 9995                 3               87.36         182341                 16
# 9996                 5               51.76         152109                  9
# 9997                 6               62.42          93176                 18
# 9998                 1               95.47         168995                 18
# 9999                 2               66.12         194360                  8
#
# [10000 rows x 15 columns]

# %% [markdown]
# # CONVERTING A DATA INTO PANDAS DATAFRAME

# %%
df=pd.DataFrame(data)
df
# Out:
#       Employee_ID  Age Department Job_Level  Years_at_Company  \
# 0               1   45  Marketing       Mid                29
# 1               2   38  Marketing       Mid                 7
# 2               3   53      Sales       Mid                 8
# 3               4   46    Finance       Mid                 4
# 4               5   28    Finance   Manager                 5
# ...           ...  ...        ...       ...               ...
# 9995         9996   54      Sales     Entry                18
# 9996         9997   37      Sales       Mid                27
# 9997         9998   56    Finance    Senior                20
# 9998         9999   57         IT    Senior                13
# 9999        10000   22         HR    Senior                19
#
#       Monthly_Hours_Worked Remote_Work  Meetings_per_Week  \
# 0                      198          No                  1
# 1                      157         Yes                 13
# 2                      146          No                  2
# 3                      200          No                  4
# 4                      193      Hybrid                 11
# ...                    ...         ...                ...
# 9995                   133          No                 14
# 9996                   187          No                  5
# 9997                   125          No                  9
# 9998                   123          No                  7
# 9999                   188          No                  1
#
#       Tasks_Completed_Per_Day  Overtime_Hours_Per_Week Work_Life_Balance  \
# 0                           7                        1              Good
# 1                           3                       10         Excellent
# 2                          15                       11              Poor
# 3                           9                        0              Poor
# 4                           9                        6              Poor
# ...                       ...                      ...               ...
# 9995                       10                        8              Good
# 9996                       15                        3              Good
# 9997                        4                       12           Average
# 9998                        7                        5           Average
# 9999                        4                        2              Poor
#
#       Job_Satisfaction  Productivity_Score  Annual_Salary  Absences_Per_Year
# 0                    5               88.73         182971                  2
# 1                    1               74.70          74217                 13
# 2                    4               67.85         176003                 16
# 3                    5               93.73          69209                  1
# 4                    7               93.30         195477                  5
# ...                ...                 ...            ...                ...
# 9995                 3               87.36         182341                 16
# 9996                 5               51.76         152109                  9
# 9997                 6               62.42          93176                 18
# 9998                 1               95.47         168995                 18
# 9999                 2               66.12         194360                  8
#
# [10000 rows x 15 columns]

# %% [markdown]
# # DESCRIPTIVE ANALYSIS

# %%
df.shape         #provides total no.of rows and columns in the df
# Out:
# (10000, 15)

# %%
df.size
# Out:
# 150000

# %%
df.head(5)        #first 5 entries of dataframe
# Out:
#    Employee_ID  Age Department Job_Level  Years_at_Company  \
# 0            1   45  Marketing       Mid                29
# 1            2   38  Marketing       Mid                 7
# 2            3   53      Sales       Mid                 8
# 3            4   46    Finance       Mid                 4
# 4            5   28    Finance   Manager                 5
#
#    Monthly_Hours_Worked Remote_Work  Meetings_per_Week  \
# 0                   198          No                  1
# 1                   157         Yes                 13
# 2                   146          No                  2
# 3                   200          No                  4
# 4                   193      Hybrid                 11
#
#    Tasks_Completed_Per_Day  Overtime_Hours_Per_Week Work_Life_Balance  \
# 0                        7                        1              Good
# 1                        3                       10         Excellent
# 2                       15                       11              Poor
# 3                        9                        0              Poor
# 4                        9                        6              Poor
#
#    Job_Satisfaction  Productivity_Score  Annual_Salary  Absences_Per_Year
# 0                 5               88.73         182971                  2
# 1                 1               74.70          74217                 13
# 2                 4               67.85         176003                 16
# 3                 5               93.73          69209                  1
# 4                 7               93.30         195477                  5

# %%
df.tail(5)              #last 5 entries of dataframe
# Out:
#       Employee_ID  Age Department Job_Level  Years_at_Company  \
# 9995         9996   54      Sales     Entry                18
# 9996         9997   37      Sales       Mid                27
# 9997         9998   56    Finance    Senior                20
# 9998         9999   57         IT    Senior                13
# 9999        10000   22         HR    Senior                19
#
#       Monthly_Hours_Worked Remote_Work  Meetings_per_Week  \
# 9995                   133          No                 14
# 9996                   187          No                  5
# 9997                   125          No                  9
# 9998                   123          No                  7
# 9999                   188          No                  1
#
#       Tasks_Completed_Per_Day  Overtime_Hours_Per_Week Work_Life_Balance  \
# 9995                       10                        8              Good
# 9996                       15                        3              Good
# 9997                        4                       12           Average
# 9998                        7                        5           Average
# 9999                        4                        2              Poor
#
#       Job_Satisfaction  Productivity_Score  Annual_Salary  Absences_Per_Year
# 9995                 3               87.36         182341                 16
# 9996                 5               51.76         152109                  9
# 9997                 6               62.42          93176                 18
# 9998                 1               95.47         168995                 18
# 9999                 2               66.12         194360                  8

# %%
df.columns              #all columns names in dataframe
# Out:
# Index(['Employee_ID', 'Age', 'Department', 'Job_Level', 'Years_at_Company',
#        'Monthly_Hours_Worked', 'Remote_Work', 'Meetings_per_Week',
#        'Tasks_Completed_Per_Day', 'Overtime_Hours_Per_Week',
#        'Work_Life_Balance', 'Job_Satisfaction', 'Productivity_Score',
#        'Annual_Salary', 'Absences_Per_Year'],
#       dtype='object')

# %%
df.info()               #provides all infomation about a dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Employee_ID              10000 non-null  int64
#  1   Age                      10000 non-null  int64
#  2   Department               10000 non-null  object
#  3   Job_Level                10000 non-null  object
#  4   Years_at_Company         10000 non-null  int64
#  5   Monthly_Hours_Worked     10000 non-null  int64
#  6   Remote_Work              10000 non-null  object
#  7   Meetings_per_Week        10000 non-null  int64
#  8   Tasks_Completed_Per_Day  10000 non-null  int64
#  9   Overtime_Hours_Per_Week  10000 non-null  int64
#  10  Work_Life_Balance        10000 non-null  object
#  11  Job_Satisfaction         10000 non-null  int64
#  12  Productivity_Score       10000 non-null  float64
#  13  Annual_Salary            10000 non-null  int64
#  14  Absences_Per_Year        10000 non-null  int64
# dtypes: float64(1), int64(10), object(4)
# memory usage: 1.1+ MB

# %%
df.describe()                     #provides statistical measures of every numerical columns
# Out:
#        Employee_ID           Age  Years_at_Company  Monthly_Hours_Worked  \
# count  10000.00000  10000.000000      10000.000000          10000.000000
# mean    5000.50000     40.655800         14.935600            169.513100
# std     2886.89568     11.005101          8.359931             28.775487
# min        1.00000     22.000000          1.000000            120.000000
# 25%     2500.75000     31.000000          8.000000            145.000000
# 50%     5000.50000     41.000000         15.000000            170.000000
# 75%     7500.25000     50.000000         22.000000            194.000000
# max    10000.00000     59.000000         29.000000            219.000000
#
#        Meetings_per_Week  Tasks_Completed_Per_Day  Overtime_Hours_Per_Week  \
# count       10000.000000              10000.00000             10000.000000
# mean            6.975200                 10.98120                 6.948000
# std             4.295606                  4.89633                 4.330332
# min             0.000000                  3.00000                 0.000000
# 25%             3.000000                  7.00000                 3.000000
# 50%             7.000000                 11.00000                 7.000000
# 75%            11.000000                 15.00000                11.000000
# max            14.000000                 19.00000                14.000000
#
#        Job_Satisfaction  Productivity_Score  Annual_Salary  Absences_Per_Year
# count      10000.000000        10000.000000   10000.000000        10000.00000
# mean           4.991600           75.389223  117257.446300            9.49360
# std            2.586232           14.450485   47410.812846            5.76471
# min            1.000000           50.000000   35001.000000            0.00000
# 25%            3.000000           62.855000   75761.750000            4.00000
# 50%            5.000000           75.535000  117645.000000            9.00000
# 75%            7.000000           88.032500  157836.750000           14.00000
# max            9.000000          100.000000  199997.000000           19.00000

# %%
df.dtypes                               #provides the data type of all columns
# Out:
# Employee_ID                  int64
# Age                          int64
# Department                  object
# Job_Level                   object
# Years_at_Company             int64
# Monthly_Hours_Worked         int64
# Remote_Work                 object
# Meetings_per_Week            int64
# Tasks_Completed_Per_Day      int64
# Overtime_Hours_Per_Week      int64
# Work_Life_Balance           object
# Job_Satisfaction             int64
# Productivity_Score         float64
# Annual_Salary                int64
# Absences_Per_Year            int64
# dtype: object

# %% [markdown]
# # FINDING UNIQUE VALUES AND VALUECOUNTS FOR EVERY COLUMNS

# %%
df['Department'].unique()            #finding unique values in the column
# Out:
# array(['Marketing', 'Sales', 'Finance', 'IT', 'Operations', 'HR'],
#       dtype=object)

# %%
df['Department'].value_counts()          #provides sum of all unique values in the column
# Out:
# Department
# Sales         1715
# HR            1684
# IT            1677
# Finance       1676
# Marketing     1642
# Operations    1606
# Name: count, dtype: int64

# %%
df['Job_Level'].unique()
# Out:
# array(['Mid', 'Manager', 'Entry', 'Senior'], dtype=object)

# %%
df['Job_Level'].value_counts()
# Out:
# Job_Level
# Mid        3949
# Entry      3062
# Senior     1954
# Manager    1035
# Name: count, dtype: int64

# %%
df['Remote_Work'].value_counts()
# Out:
# Remote_Work
# No        4042
# Hybrid    2996
# Yes       2962
# Name: count, dtype: int64

# %%
df['Work_Life_Balance'].value_counts()
# Out:
# Work_Life_Balance
# Average      4071
# Good         2961
# Poor         1989
# Excellent     979
# Name: count, dtype: int64

# %%
df['Job_Satisfaction'].value_counts()
# Out:
# Job_Satisfaction
# 6    1151
# 9    1131
# 2    1126
# 1    1118
# 3    1116
# 7    1115
# 4    1102
# 5    1076
# 8    1065
# Name: count, dtype: int64

# %%
df['Productivity_Score'].value_counts()
# Out:
# Productivity_Score
# 84.11    8
# 57.79    8
# 87.33    8
# 74.18    7
# 99.34    7
#         ..
# 57.72    1
# 90.76    1
# 95.50    1
# 53.04    1
# 97.79    1
# Name: count, Length: 4333, dtype: int64

# %% [markdown]
# # HANDLING MISSING VALUES

# %%
df.isnull().sum()                   #checking for any null values
# Out:
# Employee_ID                0
# Age                        0
# Department                 0
# Job_Level                  0
# Years_at_Company           0
# Monthly_Hours_Worked       0
# Remote_Work                0
# Meetings_per_Week          0
# Tasks_Completed_Per_Day    0
# Overtime_Hours_Per_Week    0
# Work_Life_Balance          0
# Job_Satisfaction           0
# Productivity_Score         0
# Annual_Salary              0
# Absences_Per_Year          0
# dtype: int64

# %%
df.isna().sum()            #checking for any Nan values
# Out:
# Employee_ID                0
# Age                        0
# Department                 0
# Job_Level                  0
# Years_at_Company           0
# Monthly_Hours_Worked       0
# Remote_Work                0
# Meetings_per_Week          0
# Tasks_Completed_Per_Day    0
# Overtime_Hours_Per_Week    0
# Work_Life_Balance          0
# Job_Satisfaction           0
# Productivity_Score         0
# Annual_Salary              0
# Absences_Per_Year          0
# dtype: int64

# %% [markdown]
# # HANDLING DUPLICATES

# %%
df.duplicated().sum()          #checking for duplicate values
# Out:
# np.int64(0)

# %% [markdown]
# # VISUALIZING DATA USING MATPLOTLIB AND SEABORN

# %%
df.columns
# Out:
# Index(['Employee_ID', 'Age', 'Department', 'Job_Level', 'Years_at_Company',
#        'Monthly_Hours_Worked', 'Remote_Work', 'Meetings_per_Week',
#        'Tasks_Completed_Per_Day', 'Overtime_Hours_Per_Week',
#        'Work_Life_Balance', 'Job_Satisfaction', 'Productivity_Score',
#        'Annual_Salary', 'Absences_Per_Year'],
#       dtype='object')

# %% [markdown]
# # HISTPLOTS

# %%
sns.histplot(data=df,x='Productivity_Score',bins=3,kde=True)    #ploting histogram using seaborn
plt.show()

# %%
sns.histplot(data=df,x='Monthly_Hours_Worked',bins=3,kde=True)       #ploting histogram using seaborn
plt.show()

# %% [markdown]
# # LINE PLOT

# %%
plt.plot(df['Meetings_per_Week'],df['Employee_ID'])
plt.xlabel('Meetings_per_Week')
plt.ylabel('Employee_ID')
plt.title('how employees are engaged in meetings')     
plt.show()

# %%
sns.lineplot(x=df['Job_Satisfaction'],y=df['Productivity_Score'],data=df,label='productivity score based on job satisfaction')
plt.show()

# %%
sns.lineplot(x='Department',y='Job_Satisfaction',data=df,color='green')
plt.title('jobsatisfaction by departments')
plt.show()

# %%
sns.lineplot(x=df['Job_Satisfaction'],y=df['Annual_Salary'],data=df,label='productivity score based on annual salary',color='red')
plt.show()

# %% [markdown]
# # BAR PLOT

# %%
plt.bar(df['Department'],df['Productivity_Score'])
plt.xlabel('department')
plt.ylabel('productivity score')
plt.show()

# %%
sns.barplot(x='Job_Satisfaction',y='Productivity_Score',data=df)
plt.show()

# %% [markdown]
# # SCATTER PLOT

# %%
sns.scatterplot(x=df['Monthly_Hours_Worked'],y=df['Productivity_Score'],data=df)
plt.title('hours working vs productivity score')
plt.show()

# %%
plt.scatter(df['Age'],df['Tasks_Completed_Per_Day'])
plt.xlabel('joblevel')
plt.ylabel('tasks completed per day')
plt.show()

# %% [markdown]
# # PIE CHARTS

# %%
dept_counts = df['Department'].value_counts()
p=df['Productivity_Score'].value_counts()
plt.pie(dept_counts, labels=dept_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('DEPARTMENTS')
plt.show()

# %%
overtime_counts = df['Overtime_Hours_Per_Week'].value_counts()
plt.pie(overtime_counts, labels=overtime_counts.index, autopct='%1.1f%%', 
        startangle=90)
plt.title('Overtime Distribution')
plt.show()

# %% [markdown]
# # ploting box plot to detect any outliers in dataset

# %%
import seaborn as sns
sns.boxplot(data=df)
# Out:
# <Axes: >

# %% [markdown]
# # Finding correlation between numerical columns and plotting heat map

# %%
co=df.select_dtypes(include='number').corr()
co
# Out:
#                          Employee_ID       Age  Years_at_Company  \
# Employee_ID                 1.000000  0.008597          0.013631
# Age                         0.008597  1.000000          0.004679
# Years_at_Company            0.013631  0.004679          1.000000
# Monthly_Hours_Worked        0.003167  0.021098         -0.006533
# Meetings_per_Week          -0.001850  0.001535         -0.000337
# Tasks_Completed_Per_Day    -0.004726 -0.003181         -0.001017
# Overtime_Hours_Per_Week     0.007631  0.015582          0.002689
# Job_Satisfaction            0.015837  0.002372         -0.002754
# Productivity_Score          0.000413  0.000342         -0.005539
# Annual_Salary               0.000713 -0.001713          0.001936
# Absences_Per_Year          -0.012710  0.000043         -0.010507
#
#                          Monthly_Hours_Worked  Meetings_per_Week  \
# Employee_ID                          0.003167          -0.001850
# Age                                  0.021098           0.001535
# Years_at_Company                    -0.006533          -0.000337
# Monthly_Hours_Worked                 1.000000           0.005685
# Meetings_per_Week                    0.005685           1.000000
# Tasks_Completed_Per_Day              0.002209           0.015084
# Overtime_Hours_Per_Week             -0.007026           0.008963
# Job_Satisfaction                     0.004098           0.026007
# Productivity_Score                   0.016655          -0.013293
# Annual_Salary                        0.015555          -0.003506
# Absences_Per_Year                   -0.005773          -0.021500
#
#                          Tasks_Completed_Per_Day  Overtime_Hours_Per_Week  \
# Employee_ID                            -0.004726                 0.007631
# Age                                    -0.003181                 0.015582
# Years_at_Company                       -0.001017                 0.002689
# Monthly_Hours_Worked                    0.002209                -0.007026
# Meetings_per_Week                       0.015084                 0.008963
# Tasks_Completed_Per_Day                 1.000000                 0.014034
# Overtime_Hours_Per_Week                 0.014034                 1.000000
# Job_Satisfaction                        0.018555                 0.002801
# Productivity_Score                     -0.010304                -0.006639
# Annual_Salary                          -0.018397                -0.019491
# Absences_Per_Year                      -0.011736                 0.009794
#
#                          Job_Satisfaction  Productivity_Score  Annual_Salary  \
# Employee_ID                      0.015837            0.000413       0.000713
# Age                              0.002372            0.000342      -0.001713
# Years_at_Company                -0.002754           -0.005539       0.001936
# Monthly_Hours_Worked             0.004098            0.016655       0.015555
# Meetings_per_Week                0.026007           -0.013293      -0.003506
# Tasks_Completed_Per_Day          0.018555           -0.010304      -0.018397
# Overtime_Hours_Per_Week          0.002801           -0.006639      -0.019491
# Job_Satisfaction                 1.000000           -0.016788      -0.011133
# Productivity_Score              -0.016788            1.000000       0.004806
# Annual_Salary                   -0.011133            0.004806       1.000000
# Absences_Per_Year               -0.004927           -0.009229       0.014703
#
#                          Absences_Per_Year
# Employee_ID                      -0.012710
# Age                               0.000043
# Years_at_Company                 -0.010507
# Monthly_Hours_Worked             -0.005773
# Meetings_per_Week                -0.021500
# Tasks_Completed_Per_Day          -0.011736
# Overtime_Hours_Per_Week           0.009794
# Job_Satisfaction                 -0.004927
# Productivity_Score               -0.009229
# Annual_Salary                     0.014703
# Absences_Per_Year                 1.000000

# %%
plt.figure(figsize=(15,20))
sns.heatmap(co,annot=True,cmap='YlGnBu')
plt.show()

# %% [markdown]
# # STATISTICAL ANALYSIS

# %% [markdown]
# ## Checking for Skewness for all numerical columns

# %%
a=df.select_dtypes(include='number').skew()
a
# Out:
# Employee_ID                0.000000
# Age                       -0.022056
# Years_at_Company           0.022454
# Monthly_Hours_Worked      -0.006211
# Meetings_per_Week          0.004774
# Tasks_Completed_Per_Day    0.004459
# Overtime_Hours_Per_Week    0.005865
# Job_Satisfaction           0.005270
# Productivity_Score        -0.026534
# Annual_Salary              0.006355
# Absences_Per_Year         -0.000802
# dtype: float64

# %% [markdown]
# ## Find mean value for all numerical columns

# %%
b=df.select_dtypes(include='number').mean()
b
# Out:
# Employee_ID                  5000.500000
# Age                            40.655800
# Years_at_Company               14.935600
# Monthly_Hours_Worked          169.513100
# Meetings_per_Week               6.975200
# Tasks_Completed_Per_Day        10.981200
# Overtime_Hours_Per_Week         6.948000
# Job_Satisfaction                4.991600
# Productivity_Score             75.389223
# Annual_Salary              117257.446300
# Absences_Per_Year               9.493600
# dtype: float64

# %% [markdown]
# ## Finding Kurtosis for all numerical column

# %%
k=df.select_dtypes(include='number').kurt()
k
# Out:
# Employee_ID               -1.200000
# Age                       -1.218881
# Years_at_Company          -1.193447
# Monthly_Hours_Worked      -1.192116
# Meetings_per_Week         -1.198994
# Tasks_Completed_Per_Day   -1.200766
# Overtime_Hours_Per_Week   -1.214844
# Job_Satisfaction          -1.231192
# Productivity_Score        -1.204809
# Annual_Salary             -1.191311
# Absences_Per_Year         -1.199985
# dtype: float64
